# %%
config IPCompleter.greedy = True # para o autocomplete

# %%
#importação das bibliotecas principais
import pandas as pd
import numpy as np

# %%
#carregamento da base
#base = pd.read_csv(r"C:\Users\Ed\Dropbox\!!! - Mestrado\!!! - UFAC\!! Temas - Dissertacao\Acces Control\Ed\DataSetPoliticas-versao-7.csv")
arquivo = r"C:\Users\Ed\Dropbox\!!! - Mestrado\!!! - UFAC\!! Temas - Dissertacao\## Dissertação\arquivos-politicas\BaseDeDadosPoliticas-68.csv"
base = pd.read_csv(arquivo)

# %%
base
# Out:
#         Acesso                    Organizacao                   Sujeito  \
# 0    Permitted  Hospital_Florence_Nightingale                    Médico
# 1    Forbidden  Hospital_Florence_Nightingale   Dra. Daenerys_Targaryen
# 2    Permitted  Hospital_Florence_Nightingale            Arwen_Undomiel
# 3    Forbidden  Hospital_Florence_Nightingale               Funcionário
# 4    Permitted  Hospital_Florence_Nightingale            Arwen_Undomiel
# ..         ...                            ...                       ...
# 63   Permitted                     Enfermaria              Neurologista
# 64   Permitted  Hospital_Florence_Nightingale              Neurologista
# 65   Permitted  Hospital_Florence_Nightingale               Coordenador
# 66   Permitted  Hospital_Florence_Nightingale               Coordenador
# 67   Permitted                      Ortopedia               Coordenador
#
#             Acao              Objeto  Conflito
# 0       Abertura          Documentos         0
# ...

# %%
#!pip install pandas-profiling==2.7.1
# Out:
# ...
#   Using cached numpy-1.20.3-cp37-cp37m-win32.whl (11.3 MB)
# ...
#   Using cached pandas-1.2.4-cp37-cp37m-win32.whl (8.1 MB)
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27089 sha256=06816ae26d1d5104fbe7ef86e489de9d9e133e85d10f54f9eb248a80666ad45a
#   Stored in directory: c:\users\ed\appdata\local\pip\cache\wheels\70\e1\52\5b14d250ba868768823940c3229e9950d201a26d0bd3ee8655
# ...
#   Created wheel for phik: filename=phik-0.11.2-py3-none-any.whl size=1107420 sha256=3dcc45e3da0226c083196605aea333a44578453418871470ed93f764735a1b7a
#   Stored in directory: c:\users\ed\appdata\local\pip\cache\wheels\40\98\a3\b654f24edcdcdb87d1f70d65a506fcfdf15289db129c594bcd
# Successfully built htmlmin phik
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 19.1.0
#     Uninstalling attrs-19.1.0:
#       Successfully uninstalled attrs-19.1.0
#   Rolling back uninstall of attrs
#   Moving to c:\users\ed\appdata\roaming\python\python37\site-packages\attr\
# ...

# %%
import pandas_profiling
from pandas_profiling import ProfileReport
type(base)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-c69b969c86f2> in <module>
# ----> 1 import pandas_profiling
#       2 from pandas_profiling import ProfileReport
#       3 type(base)
#
# ModuleNotFoundError: No module named 'pandas_profiling'
